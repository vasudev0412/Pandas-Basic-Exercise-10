# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries (pandas,numpy, matplotlib etc)

# %%
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Time_Series/Apple_Stock/appl_1980_2014.csv) or from the file appl_1980_2014.csv from the datasets folder.

# %%
pd.read_csv('D:/data science using python 02july2019/Pandas Basic Excerises(10)/2. Pandas Basic Exercises/Exercise Data Files/Pandas Exercise Apple Stock files/appl_1980_2014.csv')
# Out:
#             Date    Open    High     Low   Close     Volume  Adj Close
# 0     2014-07-08   96.27   96.80   93.92   95.35   65130000      95.35
# 1     2014-07-07   94.14   95.99   94.10   95.97   56305400      95.97
# 2     2014-07-03   93.67   94.10   93.20   94.03   22891800      94.03
# 3     2014-07-02   93.87   94.06   93.09   93.48   28420900      93.48
# 4     2014-07-01   93.52   94.07   93.13   93.52   38170200      93.52
# 5     2014-06-30   92.10   93.73   92.09   92.93   49482300      92.93
# 6     2014-06-27   90.82   92.00   90.77   91.98   64006800      91.98
# 7     2014-06-26   90.37   91.05   89.80   90.90   32595800      90.90
# 8     2014-06-25   90.21   90.70   89.65   90.36   36852200      90.36
# 9     2014-06-24   90.75   91.74   90.19   90.28   38988300      90.28
# 10    2014-06-23   91.32   91.62   90.60   90.83   43618200      90.83
# 11    2014-06-20   91.85   92.55   90.90   90.91  100813200      90.91
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
apple=pd.read_csv('D:/data science using python 02july2019/Pandas Basic Excerises(10)/2. Pandas Basic Exercises/Exercise Data Files/Pandas Exercise Apple Stock files/appl_1980_2014.csv')

# %%
apple.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
apple['Date']= pd.to_datetime(apple['Date'])

# %%
apple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple.set_index('Date', inplace=True)

# %%
apple.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
apple.index.is_unique
# Out:
# True

# %% [markdown]
# ### Step 8.  The index is from the most recent date. Sort the data so that the first entry is the oldest date.

# %%
apple.sort_index(ascending='False')
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 1980-12-12   28.75   28.87   28.75   28.75  117258400       0.45
# 1980-12-15   27.38   27.38   27.25   27.25   43971200       0.42
# 1980-12-16   25.37   25.37   25.25   25.25   26432000       0.39
# 1980-12-17   25.87   26.00   25.87   25.87   21610400       0.40
# 1980-12-18   26.63   26.75   26.63   26.63   18362400       0.41
# 1980-12-19   28.25   28.38   28.25   28.25   12157600       0.44
# 1980-12-22   29.63   29.75   29.63   29.63    9340800       0.46
# 1980-12-23   30.88   31.00   30.88   30.88   11737600       0.48
# 1980-12-24   32.50   32.63   32.50   32.50   12000800       0.51
# 1980-12-26   35.50   35.62   35.50   35.50   13893600       0.55
# 1980-12-29   36.00   36.13   36.00   36.00   23290400       0.56
# 1980-12-30   35.25   35.25   35.12   35.12   17220000       0.55
# 1980-12-31   34.25   34.25   34.13   34.13    8937600       0.53
# ...

# %%
apple.sort_values(by=['Date'],ascending='False')
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 1980-12-12   28.75   28.87   28.75   28.75  117258400       0.45
# 1980-12-15   27.38   27.38   27.25   27.25   43971200       0.42
# 1980-12-16   25.37   25.37   25.25   25.25   26432000       0.39
# 1980-12-17   25.87   26.00   25.87   25.87   21610400       0.40
# 1980-12-18   26.63   26.75   26.63   26.63   18362400       0.41
# 1980-12-19   28.25   28.38   28.25   28.25   12157600       0.44
# 1980-12-22   29.63   29.75   29.63   29.63    9340800       0.46
# 1980-12-23   30.88   31.00   30.88   30.88   11737600       0.48
# 1980-12-24   32.50   32.63   32.50   32.50   12000800       0.51
# 1980-12-26   35.50   35.62   35.50   35.50   13893600       0.55
# 1980-12-29   36.00   36.13   36.00   36.00   23290400       0.56
# 1980-12-30   35.25   35.25   35.12   35.12   17220000       0.55
# 1980-12-31   34.25   34.25   34.13   34.13    8937600       0.53
# ...

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
apple_business_month=apple.resample('BM').mean()
apple_business_month.head()
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 1980-12-31  30.481538  30.567692  30.443077  30.443077  2.586252e+07
# 1981-01-30  31.754762  31.826667  31.654762  31.654762  7.249867e+06
# 1981-02-27  26.480000  26.572105  26.407895  26.407895  4.231832e+06
# 1981-03-31  24.937727  25.016818  24.836364  24.836364  7.962691e+06
# 1981-04-30  27.286667  27.368095  27.227143  27.227143  6.392000e+06
#
#             Adj Close
# Date
# 1980-12-31   0.473077
# 1981-01-30   0.493810
# 1981-02-27   0.411053
# 1981-03-31   0.387727
# 1981-04-30   0.423333

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
(apple.index.max()-apple.index.min()).days
# Out:
# 12261

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
apple_months=apple.resample('BM').mean()
len(apple_months.index)
# Out:
# 404

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
pylab.rcParams['figure.figsize'] = (13.5, 9)   # Change the size of plots
apple["Adj Close"].plot(grid = True)
